# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
import os

# %%
if os.path.exists('data/leeds_msoa_2011_clipped_gen_w_num_households.shp'):
    msoas = gpd.read_file('data/leeds_msoa_2011_clipped_gen_w_num_households.shp')

# %%
msoas.head()

# %%
msoas.plot(column='ALLHH', cmap='Oranges')

# %%
import geopandas as gpd

# %%
import os

# %%
if os.path.exists('data/leeds_msoa_2011_clipped_gen_w_num_households.shp'):
    msoas = gpd.read_file('data/leeds_msoa_2011_clipped_gen_w_num_households.shp')

# %%
msoas.head()
# Out:
#     MSOA11CD   ALLHH                                           geometry
# 0  E02002330  2785.0  POLYGON ((440369.188 449848.047, 440555.510 44...
# 1  E02002331  2679.0  POLYGON ((443232.907 449882.656, 443165.656 44...
# 2  E02002332  2534.0  POLYGON ((419336.167 447036.779, 419488.188 44...
# 3  E02002333  3625.0  POLYGON ((422944.344 446111.156, 422831.125 44...
# 4  E02002334  3156.0  POLYGON ((442143.743 446356.066, 442098.000 44...

# %%
msoas.plot(column='ALLHH')
